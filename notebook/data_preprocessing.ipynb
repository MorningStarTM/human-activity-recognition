# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
from glob import glob

# %%
path_a = "E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\downstairs\\acc.csv"
path_g= "E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\downstairs\\gyro.csv"

# %%
df1 = pd.read_csv(path_a)
df2 = pd.read_csv(path_g)

# %%
df1.head()
# Out:
#    Unnamed: 0         x         y         z
# 0           0  0.525208  0.584137 -0.381042
# 1           1  0.373001  0.577896 -0.201477
# 2           2  0.430847  0.844421  0.284988
# 3           3  0.217880  1.111359  0.381912
# 4           4  0.169601  0.977951  0.148376

# %%
df2.head()
# Out:
#    Unnamed: 0         x         y         z
# 0           0  0.313564  0.818025  1.085387
# 1           1  0.838858  0.464291  0.646198
# 2           2 -0.141317 -0.000896  0.346186
# 3           3 -0.028178 -1.008873  0.038484
# 4           4  0.111079 -0.873046  0.049965

# %%
dt = pd.DataFrame({'acc_x_mean':[df1['x'].mean()],
                   'acc_y_mean':[df1['y'].mean()],
                   'acc_z_mean':[df1['z'].mean()],
                   'acc_x_std':[df1['x'].std()],
                   'acc_y_std':[df1['y'].std()],
                   'acc_z_std':[df1['z'].std()],
                   'acc_x_max':[df1['x'].max()],
                   'acc_y_max':[df1['y'].max()],
                   'acc_z_max':[df1['z'].max()],
                   'acc_x_min':[df1['x'].min()],
                   'acc_y_min':[df1['y'].min()],
                   'acc_z_min':[df1['z'].min()],
                   'gyro_x_mean':[df2['x'].mean()],
                   'gyro_y_mean':[df2['y'].mean()],
                   'gyro_z_mean':[df2['z'].mean()],
                   'gyro_x_std':[df2['x'].std()],
                   'gyro_y_std':[df2['y'].std()],
                   'gyro_z_std':[df2['z'].std()],
                   'gyro_x_max':[df2['x'].max()],
                   'gyro_y_max':[df2['y'].max()],
                   'gyro_z_max':[df2['z'].max()],
                   'gyro_x_min':[df2['x'].min()],
                   'gyro_y_min':[df2['y'].min()],
                   'gyro_z_min':[df2['z'].min()],
                   'activity':[path_a.split('\\')[-2]]
                   })

# %%
dt
# Out:
#    acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0    0.807947    0.605079   -0.078861   0.340053   0.290071   0.311237
#
#    acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# 0   2.390305   2.311157   1.070602  -0.618698  ...    1.079115    1.964364
#
#    gyro_z_std  gyro_x_max  gyro_y_max  gyro_z_max  gyro_x_min  gyro_y_min  \
# 0     0.70207    3.388801    6.080116    2.908103   -3.902423   -6.649853
#
#    gyro_z_min    activity
# 0   -2.179657  downstairs
#
# [1 rows x 25 columns]

# %%
path1 = "E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\jogging\\acc.csv"
path2 = "E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\jogging\\gyro.csv"

# %%
df_acc = pd.read_csv(path1)
df_gyr = pd.read_csv(path2)

# %%
def sample_dict(df1, df2, path):
    d = {'acc_x_mean':df1['x'].mean(),
        'acc_y_mean':df1['y'].mean(),
        'acc_z_mean':df1['z'].mean(),
        'acc_x_std':df1['x'].std(),
        'acc_y_std':df1['y'].std(),
        'acc_z_std':df1['z'].std(),
        'acc_x_max':df1['x'].max(),
        'acc_y_max':df1['y'].max(),
        'acc_z_max':df1['z'].max(),
        'acc_x_min':df1['x'].min(),
        'acc_y_min':df1['y'].min(),
        'acc_z_min':df1['z'].min(),
        'gyro_x_mean':df2['x'].mean(),
        'gyro_y_mean':df2['y'].mean(),
        'gyro_z_mean':df2['z'].mean(),
        'gyro_x_std':df2['x'].std(),
        'gyro_y_std':df2['y'].std(),
        'gyro_z_std':df2['z'].std(),
        'gyro_x_max':df2['x'].max(),
        'gyro_y_max':df2['y'].max(),
        'gyro_z_max':df2['z'].max(),
        'gyro_x_min':df2['x'].min(),
        'gyro_y_min':df2['y'].min(),
        'gyro_z_min':df2['z'].min(),
        'activity':path.split('\\')[-2]
                   }
    return d

# %%
path = "E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1"
glob(os.path.join(path, "*", "*"))
# Out:
# ['E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\downstairs\\acc.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\downstairs\\gyro.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\jogging\\acc.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\jogging\\gyro.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\sitting\\acc.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\sitting\\gyro.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\standing\\acc.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\standing\\gyro.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\upstairs\\acc.csv',
#  'E:\\github_clone\\human-activity-recognition\\data\\copy\\person_1\\upstairs\\gyro.csv',
# ...

# %%
def read_data(df, path):
    l = glob(os.path.join(path, "*", "*"))
    for i in range(0,len(l),2):
        print(l[i])
        d1, d2 = pd.read_csv(l[i]), pd.read_csv(l[i+1])
        dic = sample_dict(d1, d2, l[i])
        print(dic['activity'])
        df = df.append(dic, ignore_index=True)
    return df

# %%
temp = '../data/CollectedData/person02/'

# %%
dt = read_data(dt, path)
# Out:
# E:\github_clone\human-activity-recognition\data\copy\person_1\downstairs\acc.csv
# downstairs
# E:\github_clone\human-activity-recognition\data\copy\person_1\jogging\acc.csv
# jogging
# E:\github_clone\human-activity-recognition\data\copy\person_1\sitting\acc.csv
# sitting
# E:\github_clone\human-activity-recognition\data\copy\person_1\standing\acc.csv
# standing
# E:\github_clone\human-activity-recognition\data\copy\person_1\upstairs\acc.csv
# upstairs
# E:\github_clone\human-activity-recognition\data\copy\person_1\walking\acc.csv
# walking
# C:\Users\Ernest\AppData\Local\Temp\ipykernel_16564\3042428951.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dic, ignore_index=True)
# C:\Users\Ernest\AppData\Local\Temp\ipykernel_16564\3042428951.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
tem = "E:\github_clone\human-activity-recognition\data\copy"
folders = os.listdir(Path(tem))

# %%
for i in range(len(folders)):
    folder_path = os.path.join(tem, folders[i])
    dt = read_data(dt, folder_path)

# %%
dt
# Out:
#      acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0      0.807947    0.605079   -0.078861   0.340053   0.290071   0.311237
# 1      0.807947    0.605079   -0.078861   0.340053   0.290071   0.311237
# 2     -0.272239    1.026517   -0.092339   0.724730   1.149340   0.687125
# 3      0.281158    0.358120   -0.898597   0.041880   0.036871   0.016954
# 4      0.079849    1.003429    0.080250   0.071522   0.018363   0.053207
# ..          ...         ...         ...        ...        ...        ...
# 140   -0.113739    1.109345    0.003330   0.851508   1.551032   0.920188
# 141    0.426480    0.424818   -0.806676   0.022985   0.024301   0.021426
# 142   -0.169360    0.979190    0.101648   0.029732   0.014166   0.100020
# 143    0.223567    0.999923   -0.053368   0.441535   0.518810   0.363675
# 144    0.011534    1.044528    0.008908   0.409827   0.565162   0.450112
#
#      acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# ...

# %%
ca = "E:\\github_clone\\human-activity-recognition\\data\\custom_activity"
ca_folders = os.listdir(ca)

# %%
for i in range(len(ca_folders)):
    folder_path = os.path.join(ca, ca_folders[i])
    dt = read_data(dt, folder_path)
# Out:
# E:\github_clone\human-activity-recognition\data\custom_activity\person_1\Activity_1\Accelerometer.csv
# Activity_1
# E:\github_clone\human-activity-recognition\data\custom_activity\person_1\Activity_2\Accelerometer.csv
# Activity_2
# E:\github_clone\human-activity-recognition\data\custom_activity\person_1\Activity_3\Accelerometer.csv
# Activity_3
# E:\github_clone\human-activity-recognition\data\custom_activity\person_2\Activity_1\Accelerometer.csv
# Activity_1
# E:\github_clone\human-activity-recognition\data\custom_activity\person_2\Activity_2\Accelerometer.csv
# Activity_2
# E:\github_clone\human-activity-recognition\data\custom_activity\person_2\Activity_3\Accelerometer.csv
# Activity_3
# E:\github_clone\human-activity-recognition\data\custom_activity\person_3\Activity_1\Accelerometer.csv
# Activity_1
# E:\github_clone\human-activity-recognition\data\custom_activity\person_3\Activity_2\Accelerometer.csv
# Activity_2
# ...

# %%
dt
# Out:
#      acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0      0.807947    0.605079   -0.078861   0.340053   0.290071   0.311237
# 1      0.807947    0.605079   -0.078861   0.340053   0.290071   0.311237
# 2     -0.272239    1.026517   -0.092339   0.724730   1.149340   0.687125
# 3      0.281158    0.358120   -0.898597   0.041880   0.036871   0.016954
# 4      0.079849    1.003429    0.080250   0.071522   0.018363   0.053207
# ..          ...         ...         ...        ...        ...        ...
# 155    0.241357   -0.962269    0.196385   0.877973   0.519634   0.400193
# 156    0.159057   -1.623560    0.192615   1.207756   1.139694   0.741549
# 157    0.198082   -1.005420    0.213194   0.842492   0.649819   0.588153
# 158    0.377529   -0.909224    0.173188   0.672255   0.437775   0.283773
# 159    0.556319   -0.804833    0.221853   0.473266   0.521786   0.368918
#
#      acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# ...

# %%
new = pd.read_csv("E:\github_clone\human-activity-recognition\data\dataset.csv")
new.head()
# Out:
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %%
new.shape
# Out:
# (88588, 11)

# %%
44365 % 16
# Out:
# 13

# %%
new['activity'].value_counts()
# Out:
# 1    44365
# 0    44223
# Name: activity, dtype: int64

# %%
t = {'acc_x_mean':[],
    'acc_y_mean':[],
    'acc_z_mean':[],
    'acc_x_std':[],
    'acc_y_std':[],
    'acc_z_std':[],
    'acc_x_max':[],
    'acc_y_max':[],
    'acc_z_max':[],
    'acc_x_min':[],
    'acc_y_min':[],
    'acc_z_min':[],
    'gyro_x_mean':[],
    'gyro_y_mean':[],
    'gyro_z_mean':[],
    'gyro_x_std':[],
    'gyro_y_std':[],
    'gyro_z_std':[],
    'gyro_x_max':[],
    'gyro_y_max':[],
    'gyro_z_max':[],
    'gyro_x_min':[],
    'gyro_y_min':[],
    'gyro_z_min':[],
    'activity':[]
                   }

# %%
groups = new.groupby('activity')

# %%
group_0 = groups.get_group(0)
group_1 = groups.get_group(1)

# %%
len(group_0), len(group_1)
# Out:
# (44223, 44365)

# %%
for i in range(0, len(group_0), 30):
    temp = group_0[i:i+30]
    t['acc_x_mean'].append(temp['acceleration_x'].mean())
    t['acc_y_mean'].append(temp['acceleration_y'].mean())
    t['acc_z_mean'].append(temp['acceleration_z'].mean())
    t['acc_x_std'].append(temp['acceleration_x'].std())
    t['acc_y_std'].append(temp['acceleration_y'].std())
    t['acc_z_std'].append(temp['acceleration_z'].std())
    t['acc_x_max'].append(temp['acceleration_x'].max())
    t['acc_y_max'].append(temp['acceleration_y'].max())
    t['acc_z_max'].append(temp['acceleration_z'].max())
    t['acc_x_min'].append(temp['acceleration_x'].min())
    t['acc_y_min'].append(temp['acceleration_y'].min())
    t['acc_z_min'].append(temp['acceleration_z'].min())
    t['gyro_x_mean'].append(temp['gyro_x'].mean())
    t['gyro_y_mean'].append(temp['gyro_y'].mean())
    t['gyro_z_mean'].append(temp['gyro_z'].mean())
    t['gyro_x_std'].append(temp['gyro_x'].std())
    t['gyro_y_std'].append(temp['gyro_y'].std())
    t['gyro_z_std'].append(temp['gyro_z'].std())
    t['gyro_x_max'].append(temp['gyro_x'].max())
    t['gyro_y_max'].append(temp['gyro_y'].max())
    t['gyro_z_max'].append(temp['gyro_z'].max())
    t['gyro_x_min'].append(temp['gyro_x'].min())
    t['gyro_y_min'].append(temp['gyro_y'].min())
    t['gyro_z_min'].append(temp['gyro_z'].min())
    t['activity'].append(0)

# %%
len(t['gyro_x_max'])
# Out:
# 1475

# %%
t['activity'].append('0' * 1475)

# %%
for i in list(t.keys()):
    print(f'{i}: {len(t[i])}')
# Out:
# acc_x_mean: 1475
# acc_y_mean: 1475
# acc_z_mean: 1475
# acc_x_std: 1475
# acc_y_std: 1475
# acc_z_std: 1475
# acc_x_max: 1475
# acc_y_max: 1475
# acc_z_max: 1475
# acc_x_min: 1475
# acc_y_min: 1475
# acc_z_min: 1475
# gyro_x_mean: 1475
# gyro_y_mean: 1475
# gyro_z_mean: 1475
# gyro_x_std: 1475
# gyro_y_std: 1475
# gyro_z_std: 1475
# gyro_x_max: 1475
# gyro_y_max: 1475
# gyro_z_max: 1475
# gyro_x_min: 1475
# gyro_y_min: 1475
# gyro_z_min: 1475
# activity: 1475

# %%
df_1 = pd.DataFrame(t)

# %%
df_1
# Out:
#       acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0       0.454760   -1.002820   -0.091403   0.156823   0.217807   0.132755
# 1       0.458670   -1.004230   -0.089457   0.137964   0.233858   0.111397
# 2       0.446063   -0.991360   -0.118800   0.132023   0.198867   0.116874
# 3       0.432160   -0.991063   -0.092197   0.126881   0.190168   0.114724
# 4       0.431547   -0.995507   -0.072087   0.131386   0.256150   0.096565
# ...          ...         ...         ...        ...        ...        ...
# 1470    0.350640   -0.989880   -0.164443   0.116799   0.135382   0.121059
# 1471    0.354133   -1.011587   -0.170290   0.088991   0.136006   0.107414
# 1472    0.336883   -0.960543   -0.149090   0.119277   0.140677   0.124930
# 1473    0.361637   -0.974663   -0.221430   0.148992   0.206050   0.136594
# 1474    0.343900   -0.945667   -0.149900   0.103153   0.203243   0.115259
#
#       acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# ...

# %%
for i in range(0, len(group_0), 30):
    temp = group_1[i:i+30]
    t['acc_x_mean'].append(temp['acceleration_x'].mean())
    t['acc_y_mean'].append(temp['acceleration_y'].mean())
    t['acc_z_mean'].append(temp['acceleration_z'].mean())
    t['acc_x_std'].append(temp['acceleration_x'].std())
    t['acc_y_std'].append(temp['acceleration_y'].std())
    t['acc_z_std'].append(temp['acceleration_z'].std())
    t['acc_x_max'].append(temp['acceleration_x'].max())
    t['acc_y_max'].append(temp['acceleration_y'].max())
    t['acc_z_max'].append(temp['acceleration_z'].max())
    t['acc_x_min'].append(temp['acceleration_x'].min())
    t['acc_y_min'].append(temp['acceleration_y'].min())
    t['acc_z_min'].append(temp['acceleration_z'].min())
    t['gyro_x_mean'].append(temp['gyro_x'].mean())
    t['gyro_y_mean'].append(temp['gyro_y'].mean())
    t['gyro_z_mean'].append(temp['gyro_z'].mean())
    t['gyro_x_std'].append(temp['gyro_x'].std())
    t['gyro_y_std'].append(temp['gyro_y'].std())
    t['gyro_z_std'].append(temp['gyro_z'].std())
    t['gyro_x_max'].append(temp['gyro_x'].max())
    t['gyro_y_max'].append(temp['gyro_y'].max())
    t['gyro_z_max'].append(temp['gyro_z'].max())
    t['gyro_x_min'].append(temp['gyro_x'].min())
    t['gyro_y_min'].append(temp['gyro_y'].min())
    t['gyro_z_min'].append(temp['gyro_z'].min())
    t['activity'].append(1)

# %%
df_2 = pd.DataFrame(t)

# %%
df_2
# Out:
#       acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0       0.686353   -0.185860   -0.070347   0.488219   0.642382   0.120947
# 1       1.059453   -0.279847   -0.168200   1.107633   0.739263   0.194733
# 2       1.518873   -0.394233   -0.385680   1.812130   0.887042   0.457067
# 3       1.185497   -0.336013   -0.316443   1.490348   0.723409   0.325829
# 4       0.802533   -0.259280   -0.277437   0.754338   0.511016   0.321999
# ...          ...         ...         ...        ...        ...        ...
# 1470    0.595810   -0.265240   -0.714827   0.747309   0.813061   0.770941
# 1471    0.694860   -0.266370   -0.883077   1.045808   0.826838   1.074915
# 1472    0.843643   -0.233623   -0.852810   0.935823   0.816193   0.929165
# 1473    0.731997   -0.225710   -0.683717   1.046236   0.844206   0.844035
# 1474    0.645240   -0.362427   -0.797113   0.760054   0.773053   0.897549
#
#       acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# ...

# %%
combined_df = pd.concat([df_1, df_2], ignore_index=True)

# %%
combined_df
# Out:
#       acc_x_mean  acc_y_mean  acc_z_mean  acc_x_std  acc_y_std  acc_z_std  \
# 0       0.454760   -1.002820   -0.091403   0.156823   0.217807   0.132755
# 1       0.458670   -1.004230   -0.089457   0.137964   0.233858   0.111397
# 2       0.446063   -0.991360   -0.118800   0.132023   0.198867   0.116874
# 3       0.432160   -0.991063   -0.092197   0.126881   0.190168   0.114724
# 4       0.431547   -0.995507   -0.072087   0.131386   0.256150   0.096565
# ...          ...         ...         ...        ...        ...        ...
# 2945    0.595810   -0.265240   -0.714827   0.747309   0.813061   0.770941
# 2946    0.694860   -0.266370   -0.883077   1.045808   0.826838   1.074915
# 2947    0.843643   -0.233623   -0.852810   0.935823   0.816193   0.929165
# 2948    0.731997   -0.225710   -0.683717   1.046236   0.844206   0.844035
# 2949    0.645240   -0.362427   -0.797113   0.760054   0.773053   0.897549
#
#       acc_x_max  acc_y_max  acc_z_max  acc_x_min  ...  gyro_x_std  gyro_y_std  \
# ...

# %%
combined_df.to_csv('E:\\github_clone\\human-activity-recognition\\data\\compressed_data_0_1.csv', index=False)

# %%
dt.to_csv('E:\\github_clone\\human-activity-recognition\\data\\compressed_data_1.csv', index=False)

# %% [markdown]
# # Adding New data

# %%
df = pd.DataFrame(t)

# %%
path_ac = "E:\\github_clone\\human-activity-recognition\\data\\custom_activity"
act_folders = os.listdir(path_ac)

# %%
for i in range(len(act_folders)):
    df = read_data(df, os.path.join(path_ac, act_folders[i]))

# %%
df.to_csv('E:\\github_clone\\human-activity-recognition\\data\\compressed_activity_data.csv', index=False)
